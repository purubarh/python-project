# %%
print("Hello Arnavi")
# Out:
# Hello Arnavi

# %%
input("what is your name")
# Out:
# 'Arnavi'

# %%
name = 'arnavi'
print(name)
# Out:
# arnavi

# %%
a = True
b = False

a + b
# Out:
# 1

# %%
a + a
# Out:
# 2

# %%
import pandas as pd
