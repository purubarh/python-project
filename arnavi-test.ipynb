# %%
print("Goodmorning")
input("How did you sleep? : ")
# Out:
# Goodmorning
# '3'

# %%
ans=input("How did you sleep? : ")
if ans=='good':
    print("That is good to hear!") 
else:
    print("that is sad")
# Out:
# that is sad
